# %% [markdown]
# #### Code style
# get into the habit right away
# https://lemariva.com/blog/2019/05/analytics-beautiful-python-using-pep-8
#
# Task: make the bad example formated to meet pep8
#
# Comment: The cells are not meant to be executed.

# %% [markdown]
# #### bad example

# %%
### Indention
foo = long_function_name(var_one, var_two, 
                         var_three, var_four)


def long_function_super_langer_name(
    var_one, var_two, var_three,
    var_four):
    print(var_one)

    
### Truth statemtents
my_bool=True

if my_bool == True:
    print("hello")

my_list = []
if len(my_list) == 0:
    print("hello")

if not foo is None: pass

### Operators
income = (gross_wages +
          taxable_interest +
          (dividends - qualified_dividends) -
          ira_deduction -
          student_loan_interest)



### Spaces
spam( ham[ 1 ], { eggs: 2 } )

# variable definitions
dct ['key'] = lst [index]


x             = 1
y             = 2
long_variable = 3



# Keyword arguments / default values
def complex(real, imag = 0.0):
    return magic(r = real, i = imag)


### Compound statesments
if foo == 'blah': do_blah_thing()
do_one(); do_two(); do_three()




### Comments
x = x + 1                 # Increment x

x = x +1# Incerement x

#full line comment.

# Dies ist ein weiterer Kommentar.

def my_func():
    """ This is a block comment.
    """
    print("hallo")

# %% [markdown]
# #### good example

# %%
### Indention
foo = long_function_name(var_one, var_two,
                         var_three, var_four)

# Hanging indents should add a level.
def long_function_name(
        var_one, var_two, var_three,
        var_four):
    print(var_one)

    
### Truth statements
# Use pythonic way to check truth statements.
my_bool = True
if my_bool:
    print("hello")

my_list = []
if my_list:
    print("hello")
    
if foo is not None: pass
    

### Operators
# match operators with operands
income = (gross_wages
          + taxable_interest
          + (dividends - qualified_dividends)
          - ira_deduction
          - student_loan_interest)


### Spaces
spam(ham[1], {eggs: 2})

# variable definitions
dct['key'] = lst[index]
x = 1
y = 2
long_variable = 3

# Keywords arguments/ default values
def complex(real, imag=0.0):
    return magic(r=real, i=imag)


### Compound statesments (avoid)
if foo == 'blah':
    do_blah_thing()
do_one()
do_two()
do_three()


### Comments
x = x + 1                 # Account for borders

x = x + 1    # Account for borders

# This is a full line comment.

# This is another comment.


def my_func(name):
    """ Prints the word hallo. """
    print("hallo", name)
